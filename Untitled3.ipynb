# %%
[]
print(5+2)
# Out:
# 7

# %%
 print(5-2)
# Out:
# 3

# %%
[ ]

# %% [markdown]
# p = parentesis
# e= exponent
# m=multipication
# d= division
# a= addition
# s= subtract

# %%
 print (((1+3)*(9-2)/2 )**2)
# Out:
# 196.0

# %%
num1=5
num2=2
print(num1+num2)
# Out:
# 7

# %%
num1=10
print(num1)

num1=5
print(num1)

num1=num1+50
print(num1)
# Out:
# 10
# 5
# 55

# %%
num_years=4
days_per_year=365
hours_per_day=24
mins_per_hour=60
secs_per_min=60
total_secs=secs_per_min*mins_per_hour*hours_per_day*days_per_year*num_years
print(total_secs)
# Out:
# 126144000

# %%
days_per_year=365.25
total_secs=secs_per_min*mins_per_hour*hours_per_day*days_per_year*num_years
print(total_secs)
# Out:
# 126230400.0

# %%
print(hours_per_day)
# Out:
# 24

# %%
print(barsha rijal)
# Out:
#   File "<ipython-input-14-4f08e321b02c>", line 1
#     print(barsha rijal)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#print your name
print("barsha rijal")
# Out:
# barsha rijal

# %%
#print your name
print("barsha rijal")
# Out:
# barsha rijal

# %%
# Declare the variable
accidents_per_hour = 15

# Calculate accidents per day (assuming 24 hours in a day)
accidents_per_day = accidents_per_hour * 24

# Print the result
print("Accidents per day:", accidents_per_day)
# Out:
# Accidents per day: 360

# %%
def add(n1,n2):
  total=n1+n2
  return total

  num1=5
  num2=10

  sum=add(num1,num2)
  print(sum)

  sum=add(3,2)
  print(sum)

  sum=add(5,5)
  print(sum)

# %%
def add(n1,n2):
  total=n1+n2
  return total

# %%
  num1=5
  num2=10

  sum= add(num1,num2)
  print(sum)

  sum=add(3,2)
  print(sum)
# Out:
# 15
# 5

# %%
def get_pay(num_hours):
     #pre-tax pay,based on receiving BDT 2000/hour
     pay_pretax = num_hours * 2000
     #After-tax pay,based on being in 12% tax bracket
     pay_aftertax = pay_pretax * (1-0.12)
     return pay_aftertax

# %%
# prompt: def get_pay(num_hours):
# #pre-tax pay,based on receiving BDT 2000/hour
#      pay_pretax = num_hours * 2000
# #After-tax pay,based on being in 12% tax bracket
#     pay_aftertax = pay_pretax * (1-0.12)
#     return pay_aftertax
#  solv it

def get_pay(num_hours):
    #pre-tax pay,based on receiving BDT 2000/hour
    pay_pretax = num_hours * 2000
    #After-tax pay,based on being in 12% tax bracket
    pay_aftertax = pay_pretax * (1-0.12)
    return pay_aftertax

# %%
def get_pay(num_hours):
    #pre-tax pay,based on receiving BDT 2000/hour
    pay_pretax = num_hours * 2000
    #After-tax pay,based on being in 12% tax bracket
    pay_aftertax = pay_pretax * (1-0.12)
    return pay_aftertax

# %%
payment= get_pay(80)
print(payment)
# Out:
# 140800.0

# %%
print(f"you will get {payment} BDT")
# Out:
# you will get 140800.0 BDT

# %%
def get_expected_cost(beds, baths):

    initial_cost = 80000


    cost_per_bedroom = 30000
    cost_per_bathroom = 10000


    expected_cost = initial_cost + (beds * cost_per_bedr and bathroomo) + (baths * cost_per_bathroom)

    return expected_cost

# %%
print(get_expected_cost(1, 1))  # Expected output: 120000
print(get_expected_cost(2, 1))  # Expected output: 150000
# Out:
# 120000
# 150000

# %%
def get_expected_cost(beds, baths):


    base_cost = 80000


    cost_per_bedroom = 30000
    cost_per_bathroom = 10000


    expected_cost = base_cost + (beds * cost_per_bedroom) + (baths * cost_per_bathroom)


    return expected_cost

# Example usage
print("Expected cost (1 bed, 1 bath):", get_expected_cost(1, 1))
print("Expected cost (2 beds, 1 bath):", get_expected_cost(2, 1))
# Out:
# Expected cost (1 bed, 1 bath): 120000
# Expected cost (2 beds, 1 bath): 150000
