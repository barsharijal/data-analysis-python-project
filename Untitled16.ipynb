# %%
land_slides = pd.read_csv("/content/land_slides.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-499475eb2ce7> in <cell line: 1>()
# ----> 1 land_slides = pd.read_csv("/content/land_slides.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# %%
land_slides = pd.read_csv("/content/land_slides.csv")
