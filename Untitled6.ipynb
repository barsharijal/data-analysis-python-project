# %%
goldbase_cost = 50
engraving_cost_per_unit = 7
solidbase_cost = 100
engraving_cost_per_unit =10
total_cost = base_cost +(engraved_uits*engraving_cost_per_unit)
returntotal_cost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c9813444562e> in <cell line: 5>()
#       3 solidbase_cost = 100
#       4 engraving_cost_per_unit =10
# ----> 5 total_cost = base_cost +(engraved_uits*engraving_cost_per_unit)
#       6 returntotal_cost
#       7
#
# NameError: name 'base_cost' is not defined

# %%
def cost_of_project(engraving,solid_gold,_):
    cost = solid_gold *(100 + len(engraving)*10)+(not_solid_gold*(50+len(engraving)*7))
    return cost


    project_one = cost_of_project("Tonoy",True )
print(project_one)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-129b7b3190e9> in <cell line: 7>()
#       5
#       6     project_one = cost_of_project("Tonoy",True )
# ----> 7 print(project_one)
#
# NameError: name 'project_one' is not defined

# %%
project_one = cost_of_project("Tonoy",True )
print(project_one)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c9b09eed70f2> in <cell line: 1>()
# ----> 1 project_one = cost_of_project("Tonoy",True )
#       2 print(project_one)
#
# <ipython-input-5-b641acd7116a> in cost_of_project(engraving, solid_gold)
#       1 def cost_of_project(engraving,solid_gold):
# ----> 2     cost = solid_gold *(100 + len(engraving)*10)+(not_solid_gold*(50+len(engraving)*7))
#       3     return cost
#
# NameError: name 'not_solid_gold' is not defined

# %%
marks = 80
if marks > 85:
    print("A")
